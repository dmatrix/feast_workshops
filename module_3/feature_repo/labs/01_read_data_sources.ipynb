# %%
import pandas as pd

# %% [markdown]
# ### Read the data files

# %%
#  # [IMPORTANT] Change this  path to yours git repo
ZIPCODE_TABLE = "/Users/jules/git-repos/feast_workshops/module_3/feature_repo/data/zipcode_table.parquet"
CREDIT_HISTORY_TABLE="/Users/jules/git-repos/feast_workshops/module_3/feature_repo/data/credit_history.parquet"
LOANS_TABLE = "/Users/jules/git-repos/feast_workshops/module_3/feature_repo/data/loan_table.parquet"

# %%
def get_data_from_file(file: str) -> pd.DataFrame:
    df = pd.read_parquet(file)
    return df

# %%
zip_df = get_data_from_file(ZIPCODE_TABLE)
zip_df.head(5)
# Out:
#    zipcode                city state location_type  tax_returns_filed  \
# 0     7675            WESTWOOD    NJ       PRIMARY              13245
# 1     7677      WOODCLIFF LAKE    NJ       PRIMARY               2945
# 2     7885             WHARTON    NJ       PRIMARY               5273
# 3     7981            WHIPPANY    NJ       PRIMARY               4585
# 4     8889  WHITEHOUSE STATION    NJ       PRIMARY               4691
#
#    population  total_wages           event_timestamp         created_timestamp
# 0       24083   1089095041 2017-01-01 12:00:00+00:00 2017-01-01 12:00:00+00:00
# 1        5471    325436960 2017-01-01 12:00:00+00:00 2017-01-01 12:00:00+00:00
# 2        8999    240827990 2017-01-01 12:00:00+00:00 2017-01-01 12:00:00+00:00
# 3        8057    292096795 2017-01-01 12:00:00+00:00 2017-01-01 12:00:00+00:00
# 4        8570    401312434 2017-01-01 12:00:00+00:00 2017-01-01 12:00:00+00:00

# %%
credit_df = get_data_from_file(CREDIT_HISTORY_TABLE)
credit_df.head(5)
# Out:
#              event_timestamp        dob_ssn  credit_card_due  mortgage_due  \
# 0 2020-04-26 18:01:04.746575  19530219_5179             8419         91803
# 1 2020-04-26 18:01:04.746575  19781116_7723             2944        741165
# 2 2020-04-26 18:01:04.746575  19931128_5771              833        976522
# 3 2020-04-26 18:01:04.746575  19500806_6783             5936       1553523
# 4 2020-04-26 18:01:04.746575  19620322_7692             1575       1067381
#
#    student_loan_due  vehicle_loan_due  hard_pulls  missed_payments_2y  \
# 0             22328             15078           0                   1
# 1              2515             28605           0                   3
# 2             33000             21733           9                   7
# 3             48955             26219           1                   0
# 4              9501             15814           1                   1
#
#    missed_payments_1y  missed_payments_6m  bankruptcies  \
# ...

# %%
loans_df = get_data_from_file(LOANS_TABLE)
loans_df.head(5)
# Out:
#    loan_id        dob_ssn  zipcode  person_age  person_income  \
# 0    10000  19530219_5179    76104          22          59000
# 1    10001  19520816_8737    70380          21           9600
# 2    10002  19860413_2537    97039          25           9600
# 3    10003  19760701_8090    63785          23          65500
# 4    10004  19830125_8297    82223          24          54400
#
#   person_home_ownership  person_emp_length loan_intent  loan_amnt  \
# 0                  RENT              123.0    PERSONAL      35000
# 1                   OWN                5.0   EDUCATION       1000
# 2              MORTGAGE                1.0     MEDICAL       5500
# 3                  RENT                4.0     MEDICAL      35000
# 4                  RENT                8.0     MEDICAL      35000
#
#    loan_int_rate  loan_status                  event_timestamp  \
# 0          16.02            1 2021-08-25 20:34:41.361000+00:00
# 1          11.14            0 2021-08-25 20:16:20.128000+00:00
# ...
